# %%
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
import pandas as pd

# Load the dataset
file_path = r"C:\Users\ASUS\Downloads\merge-csv.com__658b20e445e1c.csv"
dataset = pd.read_csv(file_path)

# Keep only the Energy (kcal) column and modify its format
dataset['Energy (kcal)'] = dataset['Energy (kcal) kJ'].apply(lambda x: f"({x.split()[0]})")

# Drop the original Energy (kcal) kJ column
dataset.drop(columns=['Energy (kcal) kJ'], inplace=True)

# Save the modified dataset to a new CSV file
output_file_path = r"C:\Users\ASUS\Downloads\modified_dataset.csv"
dataset.to_csv(output_file_path, index=False)

print("Modified dataset saved successfully.")
# Out:
# Modified dataset saved successfully.

# %%
import pandas as pd

# Load the dataset
file_path = r"C:\Users\ASUS\Downloads\merge-csv.com__658b20e445e1c.csv"
dataset = pd.read_csv(file_path)

# Extract and convert Energy (kcal) kJ column to integer
dataset['Energy (kcal)'] = dataset['Energy (kcal) kJ'].str.extract(r'\((\d+)\)').astype(int)

# Drop the original Energy (kcal) kJ column
dataset.drop(columns=['Energy (kcal) kJ'], inplace=True)

# Save the modified dataset to a new CSV file
output_file_path = r"C:\Users\ASUS\Downloads\modify_dataset.csv"
dataset.to_csv(output_file_path, index=False)

print("Modified dataset saved successfully.")
# Out:
# Modified dataset saved successfully.

# %%
import pandas as pd

# Load the dataset
file_path = r"C:\Users\ASUS\Downloads\modify_dataset.csv"
dataset = pd.read_csv(file_path)

# Select the first 150 rows
subset_dataset = dataset.head(150)

# Save the subset dataset to a new CSV file
output_file_path = r"C:\Users\ASUS\Downloads\subset_dataset.csv"
subset_dataset.to_csv(output_file_path, index=False)

print("Subset dataset saved successfully.")
# Out:
# Subset dataset saved successfully.

# %%
import pandas as pd

# Example 2: Raw string
dataset_path = r"C:\Users\ASUS\Downloads\subset_dataset.csv"

# Read the dataset into a Pandas DataFrame
data = pd.read_csv(dataset_path)
dataset = data.drop(['Food name in English'], axis=1)
dataset = dataset.drop(['Food name in Bengali'], axis=1)

# %%
dataset
# Out:
#      Energy (kcal)  Protein (g)  Fat (g)  Carbohydrate available (g)  \
# 0              324         10.9      2.2                        56.4
# 1              344          5.8     10.0                        56.6
# 2              270          8.8      2.8                        50.9
# 3              272          8.0      1.4                        55.6
# 4              355          6.9      3.9                        69.6
# ..             ...          ...      ...                         ...
# 145            101          2.2      0.2                        20.6
# 146            113          2.4      0.2                        23.1
# 147             74          1.2      0.1                        15.1
# 148             83          1.3      0.1                        16.9
# 149             82          1.5      0.2                        16.6
#
#      Total dietary fibre (g)  Ash (g)  Na(mg)  Remarks
# 0                       17.3      1.5       4        1
# ...

# %%
import pandas as pd
import numpy as np
# first neural network with keras tutorial
from numpy import loadtxt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt

# %%
import seaborn as sns
dataset['Remarks'].value_counts().plot(kind='bar')
#input and output variables
X = dataset.iloc[:,0:7]
Y = dataset.iloc[:,7]

# %%
import pandas as pd

# Load the dataset
file_path = r"C:\Users\ASUS\Downloads\modify_dataset.csv"
dataset = pd.read_csv(file_path)

# Select the first 75 rows where "Remarks" column value is 1
subset_remarks_1 = dataset[dataset['Remarks'] == 1].head(75)

# Select the first 75 rows where "Remarks" column value is 0
subset_remarks_0 = dataset[dataset['Remarks'] == 0].head(75)

# Concatenate the two subsets
subset_dataset = pd.concat([subset_remarks_1, subset_remarks_0], ignore_index=True)

# Save the subset dataset to a new CSV file
output_file_path = r"C:\Users\ASUS\Downloads\sub_dataset.csv"
subset_dataset.to_csv(output_file_path, index=False)

print("Subset dataset saved successfully.")
# Out:
# Subset dataset saved successfully.

# %%
import pandas as pd

# Example 2: Raw string
dataset_path = r"C:\Users\ASUS\Downloads\sub_dataset.csv"

# Read the dataset into a Pandas DataFrame
data = pd.read_csv(dataset_path)
dataset = data.drop(['Food name in English'], axis=1)
dataset = dataset.drop(['Food name in Bengali'], axis=1)
dataset
# Out:
#      Energy (kcal)  Protein (g)  Fat (g)  Carbohydrate available (g)  \
# 0              324         10.9      2.2                        56.4
# 1              355          6.9      3.9                        69.6
# 2              344          9.9      3.4                        64.7
# 3              344         10.4      4.3                        61.7
# 4              341         11.2      4.2                        60.3
# ..             ...          ...      ...                         ...
# 145             81         17.0      1.4                         0.0
# 146            123         17.5      6.0                         0.0
# 147             94         16.6      3.1                         0.0
# 148             91         17.3      2.4                         0.0
# 149            101         17.2      3.5                         0.0
#
#      Total dietary fibre (g)  Ash (g)  Na(mg)  Remarks
# 0                       17.3      1.5     4.0        1
# ...

# %%
import pandas as pd
import numpy as np
# first neural network with keras tutorial
from numpy import loadtxt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt

# %%
import seaborn as sns
dataset['Remarks'].value_counts().plot(kind='bar')
#input and output variables
X = dataset.iloc[:,0:7]
Y = dataset.iloc[:,7]

# %%
import pandas as pd

# Load the dataset
file_path = r"C:\Users\ASUS\Downloads\modify_dataset.csv"
dataset = pd.read_csv(file_path)

# Select the first 75 rows where "Remarks" column value is 1
subset_remarks_1 = dataset[dataset['Remarks'] == 1].head(75)

# Select the first 75 rows where "Remarks" column value is 0
subset_remarks_0 = dataset[dataset['Remarks'] == 0].head(75)

# Concatenate the two subsets
subset_dataset = pd.concat([subset_remarks_1, subset_remarks_0], ignore_index=True)

# Save the subset dataset to a new CSV file
output_file_path = r"C:\Users\ASUS\Documents\subset_dataset.csv"
subset_dataset.to_csv(output_file_path, index=False)

# Get the indices of rows not included in the subset
other_indices = set(dataset.index) - set(subset_dataset.index)

# Create a dataframe of the other rows
others_dataset = dataset.loc[other_indices]

# Save the other rows to a new CSV file
others_output_file_path = r"C:\Users\ASUS\Documents\others_dataset.csv"
others_dataset.to_csv(others_output_file_path, index=False)

print("Subset dataset and other rows saved successfully.")
# Out:
# Subset dataset and other rows saved successfully.
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12976\2627808325.py:24: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   others_dataset = dataset.loc[other_indices]

# %%
import pandas as pd

# Load the dataset
file_path = r"C:\Users\ASUS\Downloads\BD train data.csv"
dataset = pd.read_csv(file_path)

# Sort the dataset based on the "Remarks" column
remarks_1 = dataset[dataset['Remarks'] == 1]
remarks_0 = dataset[dataset['Remarks'] == 0]

# Ensure equal number of rows for both Remarks
min_rows = min(len(remarks_1), len(remarks_0))
remarks_1 = remarks_1.head(min_rows)
remarks_0 = remarks_0.head(min_rows)

# Create an empty DataFrame to store the sorted rows
sorted_dataset = pd.DataFrame(columns=dataset.columns)

# Merge the DataFrames alternatively
for index in range(min_rows):
    sorted_dataset = sorted_dataset.append(remarks_1.iloc[index], ignore_index=True)
    sorted_dataset = sorted_dataset.append(remarks_0.iloc[index], ignore_index=True)

# Save the sorted dataset to a new CSV file
output_file_path = r"C:\Users\ASUS\Downloads\Final_train.csv"
sorted_dataset.to_csv(output_file_path, index=False)

print("Sorted dataset saved successfully.")
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12976\1476467678.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sorted_dataset = sorted_dataset.append(remarks_1.iloc[index], ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12976\1476467678.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sorted_dataset = sorted_dataset.append(remarks_0.iloc[index], ignore_index=True)
# Sorted dataset saved successfully.
