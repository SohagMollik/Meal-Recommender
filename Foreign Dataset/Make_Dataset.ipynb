# %%
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
import pandas as pd

# Replace the file path with your actual file path
file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 1\Table 1_1_Cereals and their products.xlsx"

# Read Excel file
df = pd.read_excel(file_path)

# Display the first few rows of the DataFrame to verify that it was read successfully
df
# Out:
#               Code                   Food name in English  \
# 0          01_0001               Barley, whole-grain, raw
# 1   SD or min- max                                    NaN
# 2                n                                    NaN
# 3          01_0034                        Biscuit, sweet*
# 4          01_0002                        Bread, bun/roll
# 5   SD or min- max                                    NaN
# 6                n                                    NaN
# 7          01_0003             Bread, white, for toasting
# 8   SD or min- max                                    NaN
# 9                n                                    NaN
# 10         01_0004         Maize/corn flour, whole, white
# 11  SD or min- max                                    NaN
# 12               n                                    NaN
# 13         01_0005         Maize/corn, yellow, dried, raw
# 14  SD or min- max                                    NaN
# ...

# %%
import pandas as pd

# Replace the file path with your actual file path
file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 1\Table 1_1_Cereals and their products.xlsx"

# Read Excel file
df = pd.read_excel(file_path)

# Drop rows with NaN values
df_cleaned = df.dropna()

# Display the first few rows of the cleaned DataFrame
df_cleaned
# Out:
#        Code                   Food name in English  \
# 0   01_0001               Barley, whole-grain, raw
# 3   01_0034                        Biscuit, sweet*
# 4   01_0002                        Bread, bun/roll
# 7   01_0003             Bread, white, for toasting
# 10  01_0004         Maize/corn flour, whole, white
# 13  01_0005         Maize/corn, yellow, dried, raw
# 16  01_0006                   Millet, Foxtail, raw
# 19  01_0007        Millet, Proso, whole-grain, raw
# 22  01_0008          Pear millet, whole-grain, raw
# 25  01_0035                        Plain Khichuri*
# 26  01_0036                           Plain pulao*
# 27  01_0009            Popcorn, maize (salt added)
# 30  01_0010                            Rice flaked
# 33  01_0011  Rice flakes, white grain, watersoaked
# 36  01_0012    Rice, BR-28, parboiled, milled, raw
#
#                              Food name in Bengali  Edible portion coefficient  \
# ...

# %%
import pandas as pd

# Replace the file path with your actual file path
file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 1\Table 1_1_Cereals and their products.xlsx"

# Read Excel file
df = pd.read_excel(file_path)

# Drop rows with NaN values
df_cleaned = df.dropna()

# Display the first few rows of the cleaned DataFrame
data = df_cleaned.drop(['Code'], axis=1)

# %%
data
# Out:
#                      Food name in English  \
# 0                Barley, whole-grain, raw
# 3                         Biscuit, sweet*
# 4                         Bread, bun/roll
# 7              Bread, white, for toasting
# 10         Maize/corn flour, whole, white
# 13         Maize/corn, yellow, dried, raw
# 16                   Millet, Foxtail, raw
# 19        Millet, Proso, whole-grain, raw
# 22          Pear millet, whole-grain, raw
# 25                        Plain Khichuri*
# 26                           Plain pulao*
# 27            Popcorn, maize (salt added)
# 30                            Rice flaked
# 33  Rice flakes, white grain, watersoaked
# 36    Rice, BR-28, parboiled, milled, raw
#
#                              Food name in Bengali  Edible portion coefficient  \
# 0                                      Jaab, gota                         1.0
# 3                                   Misti biscuit                         1.0
# ...

# %%
import pandas as pd

# Replace the file path with your actual file path
file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 1\Table 1_1_Cereals and their products.xlsx"

# Read Excel file
df = pd.read_excel(file_path)

# Drop rows with NaN values
df_cleaned = df.dropna()

# Remove the 'Code' column
data = df_cleaned.drop(['Code'], axis=1)

# Save the cleaned DataFrame to a CSV file
csv_file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 1\Table_1_1_Cleaned_Data.csv"
data.to_csv(csv_file_path, index=False)

# Display the first few rows of the cleaned DataFrame
data
# Out:
#                      Food name in English  \
# 0                Barley, whole-grain, raw
# 3                         Biscuit, sweet*
# 4                         Bread, bun/roll
# 7              Bread, white, for toasting
# 10         Maize/corn flour, whole, white
# 13         Maize/corn, yellow, dried, raw
# 16                   Millet, Foxtail, raw
# 19        Millet, Proso, whole-grain, raw
# 22          Pear millet, whole-grain, raw
# 25                        Plain Khichuri*
# 26                           Plain pulao*
# 27            Popcorn, maize (salt added)
# 30                            Rice flaked
# 33  Rice flakes, white grain, watersoaked
# 36    Rice, BR-28, parboiled, milled, raw
#
#                              Food name in Bengali  Edible portion coefficient  \
# 0                                      Jaab, gota                         1.0
# 3                                   Misti biscuit                         1.0
# ...

# %%
import pandas as pd

# Replace the file path with your actual file path
file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 1\Table 1_7_Cereals and their products.xlsx"

# Read Excel file
df = pd.read_excel(file_path)

# Drop rows with NaN values
df_cleaned = df.dropna()

# Remove the 'Code' column
data = df_cleaned.drop(['Code'], axis=1)

# Save the cleaned DataFrame to a CSV file
csv_file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 1\Table_1_7_Cleaned_Data.csv"
data.to_csv(csv_file_path, index=False)

# Display the first few rows of the cleaned DataFrame
data
# Out:
#                                  Food name in English  \
# 0          Rice, white, sunned, polished, milled, raw
# 3   Rice, white, sunned, polished, milled, boiled*...
# 4                                               Ruti*
# 5                                Semolina, wheat, raw
# 8                                        Sorghum, raw
# 11                Sweet corn, yellow, on the cob, raw
# 14                             Vermicelli, wheat, raw
# 17                 Vermicelli, boiled* (without salt)
# 18               Wheat flour, brown, whole grain, raw
# 21                                Wheat, flour, white
# 24                        Wheat flour, white, refined
# 27                                  Wheat, whole, raw
#
#                Food name in Bengali  Edible portion coefficient  \
# 0   Chal, atop, HYV, kolechata, raw                        1.00
# 3             Bhat, Atop, bosa bhat                        1.00
# 4                              Ruti                        1.00
# ...

# %%
import pandas as pd

# Replace the file path with your actual file path
file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 2\Table 2_1_Pulses, legumes and their.xlsx"

# Read Excel file
df = pd.read_excel(file_path)

# Drop rows with NaN values
df_cleaned = df.dropna()

# Remove the 'Code' column
data = df_cleaned.drop(['Code'], axis=1)

# Save the cleaned DataFrame to a CSV file
csv_file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 1\Table_2_1_Cleaned_Data.csv"
data.to_csv(csv_file_path, index=False)

# Display the first few rows of the cleaned DataFrame
data
# Out:
#                           Food name in English  \
# 0     Bengal gram, dehulled, split, dried, raw
# 3               Bengal gram, whole, dried, raw
# 6   Bengal gram, whole, boiled* (without salt)
# 7             Black gram, dehulled, dried, raw
# 10               Black gram, split, dried, raw
# 13               Green gram, split, dried, raw
# 17   Green gram, split, boiled* (without salt)
# 18               Green gram, whole, dried, raw
# 21                Grass pea, split, dried, raw
# 24    Grass pea, split, boiled* (without salt)
# 25                          Lentil, dried, raw
# 28              Lentil, boiled* (without salt)
# 29                             Pea, dried, raw
# 32                 Pea, boiled* (without salt)
# 33                 Red gram, split, dried, raw
# 36                         Soybean, dried, raw
#
#                Food name in Bengali  Edible portion coefficient  \
# 0                 Cholar dal, vanga                         1.0
# ...

# %%
import pandas as pd

# Replace the file path with your actual file path
file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 3\Table 3_1_Vegetables and their products.xlsx"

# Read Excel file
df = pd.read_excel(file_path)

# Drop rows with NaN values
df_cleaned = df.dropna()

# Remove the 'Code' column
data = df_cleaned.drop(['Code'], axis=1)

# Save the cleaned DataFrame to a CSV file
csv_file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 1\Table_3_1_Cleaned_Data.csv"
data.to_csv(csv_file_path, index=False)

# Display the first few rows of the cleaned DataFrame
data
# Out:
#                              Food name in English  \
# 0                             Amaranth, stem, raw
# 3                       Bean, scarlet runner, raw
# 6                       Bean, seeds and pods, raw
# 9                             Beet root, red, raw
# 12                     Brinjal, purple, long, raw
# 15  Brinjal, purple, long, boiled* (without salt)
# 16                               Broad beans, raw
# 19                                   Cabbage, raw
# 22                Cabbage, boiled* (without salt)
# 23                                    Carrot, raw
# 26                 Carrot, boiled* (without salt)
# 27                               Cauliflower, raw
# 30            Cauliflower, boiled* (without salt)
# 31                 Chilli, green, with seeds, raw
# 34                    Cowpea, pods and seeds, raw
# 37                 Cowpea, boiled* (without salt)
# 38                          Cucumber, peeled, raw
#
# ...

# %%
import pandas as pd

# Replace the file path with your actual file path
file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 3\Table 3_4_Vegetables and their products.xlsx"

# Read Excel file
df = pd.read_excel(file_path)

# Drop rows with NaN values
df_cleaned = df.dropna()

# Remove the 'Code' column
data = df_cleaned.drop(['Code'], axis=1)

# Save the cleaned DataFrame to a CSV file
csv_file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 3\Table_3_4_Cleaned_Data.csv"
data.to_csv(csv_file_path, index=False)

# Display the first few rows of the cleaned DataFrame
data
# Out:
#                           Food name in English        Food name in Bengali  \
# 0                         Drumstick, pods, raw                  Sajna data
# 3                                  Garlic, raw                       Rosun
# 6                              Gourd, ash, raw                   Chalkumra
# 9                           Gourd, bitter, raw                      Korola
# 12       Gourd, bitter, boiled* (without salt)  Korola siddha, lobon chara
# 14                          Gourd, bottle, raw                         Lau
# 17                         Gourd, pointed, raw                       Potol
# 20      Gourd, pointed, boiled* (without salt)   Potol siddha, lobon chara
# 21                           Gourd, ridge, raw                      Jhinga
# 24                           Gourd, snake, raw                   Chichinga
# 27                          Gourd, sponge, raw                     Dhundul
# ...

# %%
import pandas as pd

# Replace the file path with your actual file path
file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 3\Table 3_7_Vegetables and their products.xlsx"

# Read Excel file
df = pd.read_excel(file_path)

# Drop rows with NaN values
df_cleaned = df.dropna()

# Remove the 'Code' column
data = df_cleaned.drop(['Code'], axis=1)

# Save the cleaned DataFrame to a CSV file
csv_file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 3\Table_3_7_Cleaned_Data.csv"
data.to_csv(csv_file_path, index=False)

# Display the first few rows of the cleaned DataFrame
data
# Out:
#                          Food name in English  \
# 0                         Papaya, unripe, raw
# 3      Papaya, unripe, boiled* (without salt)
# 4                                   Peas, raw
# 7                               Plantain, raw
# 10           Plantain, boiled* (without salt)
# 11                               Pumpkin, raw
# 14            Pumpkin, boiled* (without salt)
# 15                                Radish, raw
# 18             Radish, boiled* (without salt)
# 19                         Tomato, green, raw
# 22                     Tomato, red, ripe, raw
# 25  Tomato, red, ripe, boiled* (without salt)
# 26                                Turnip, raw
#
#                Food name in Bengali  Edible portion coefficient  \
# 0                       Kancha pepe                        0.66
# 3   Kancha pepe siddha, lobon chara                        1.00
# 4                        Motorshuti                        0.53
# ...

# %%
import pandas as pd

# Replace the file path with your actual file path
file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 4\Table 4_1_Leafy vegetables.xlsx"

# Read Excel file
df = pd.read_excel(file_path)

# Drop rows with NaN values
df_cleaned = df.dropna()

# Remove the 'Code' column
data = df_cleaned.drop(['Code'], axis=1)

# Save the cleaned DataFrame to a CSV file
csv_file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 4\Table_4_1_Cleaned_Data.csv"
data.to_csv(csv_file_path, index=False)

# Display the first few rows of the cleaned DataFrame
data
# Out:
#                                Food name in English  \
# 0                                       Agathi, raw
# 6                     Amaranth, leaves, spiney, raw
# 9                        Amaranth, leaves, red, raw
# 12    Amaranth, leaves, red, boiled* (without salt)
# 13                     Amaranth, leaves, green, raw
# 16  Amaranth, leaves, green, boiled* (without salt)
# 17                                 Dock leaves, raw
# 20                               Beet greens leaves
# 23                    Bengal dayflower, leaves, raw
# 26                  Bitter gourd leaves, green, raw
# 29                         Bottle gourd leaves, raw
# 32                                   Bugleweed, raw
# 35                             Cassava, leaves, raw
# 38                     Colocasia leaves, black, raw
#
#                    Food name in Bengali  Edible portion coefficient  \
# 0                          Bok ful shak                        1.00
# ...

# %%
import pandas as pd

# Replace the file path with your actual file path
file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 4\Table 4_4_Leafy vegetables.xlsx"

# Read Excel file
df = pd.read_excel(file_path)

# Drop rows with NaN values
df_cleaned = df.dropna()

# Remove the 'Code' column
data = df_cleaned.drop(['Code'], axis=1)

# Save the cleaned DataFrame to a CSV file
csv_file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 4\Table_4_4_Cleaned_Data.csv"
data.to_csv(csv_file_path, index=False)

# Display the first few rows of the cleaned DataFrame
data
# Out:
#                                Food name in English  \
# 0                      Colocasia leaves, green, raw
# 3                               Cowpea, leaves, raw
# 6                                  Dima leaves, raw
# 9                            Drumstick, leaves, raw
# 12                                Fern, leaves, raw
# 15                           Fenugreek, leaves, raw
# 18                              Indian spinach, raw
# 22                                 Jute leaves, raw
# 25                              Pumpkin leaves, raw
# 28                               Radish leaves, raw
# 31                     Slender amaranth leaves, raw
# 34  Slender amaranth leaves, boiled* (without salt)
# 35                                     Spinach, raw
# 38                  Spinach, boiled* (without salt)
# 39                         Sweet potato leaves, raw
#
#                Food name in Bengali  Edible portion coefficient  \
# ...

# %%
import pandas as pd

# Replace the file path with your actual file path
file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 4\Table 4_7_Leafy vegetables.xlsx"

# Read Excel file
df = pd.read_excel(file_path)

# Drop rows with NaN values
df_cleaned = df.dropna()

# Remove the 'Code' column
data = df_cleaned.drop(['Code'], axis=1)

# Save the cleaned DataFrame to a CSV file
csv_file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 4\Table_4_7_Cleaned_Data.csv"
data.to_csv(csv_file_path, index=False)

# Display the first few rows of the cleaned DataFrame
data
# Out:
#                                  Food name in English  Food name in Bengali  \
# 3   Sweet potato leaves, SP7,  dark green, mature,...  Misti alu shak (SP7)
# 6   Sweet potato leaves, SP8, light green, mature,...  Misti alu shak (SP8)
# 9                                  Water spinach, raw           Kolmee shak
# 12                                    Watercress, raw         Helencha shak
#
#     Edible portion coefficient Energy (kcal) kJ  Water (g)  Protein (g)  \
# 3                         1.00         (45) 185       82.4          4.9
# 6                         1.00         (50) 206       82.6          3.6
# 9                         0.71         (43) 179       87.1          1.9
# 12                        0.75         (49) 206       87.4          2.0
#
#     Fat (g)  Carbohydrate available (g)  Total dietary fibre (g) Ash (g)
# 3       0.3                         1.2                      8.5     2.7
# 6       0.4                         3.9                      8.0     1.6
# ...

# %%
import pandas as pd

# Replace the file path with your actual file path
file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 5\Table 5_1_Starchy roots, tubers and their products.xlsx"

# Read Excel file
df = pd.read_excel(file_path)

# Drop rows with NaN values
df_cleaned = df.dropna()

# Remove the 'Code' column
data = df_cleaned.drop(['Code'], axis=1)

# Save the cleaned DataFrame to a CSV file
csv_file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 5\Table 5_1_Cleaned_Data.csv"
data.to_csv(csv_file_path, index=False)

# Display the first few rows of the cleaned DataFrame
data
# Out:
#                                  Food name in English  \
# 0                           Colocasia/Taro, corm, raw
# 3              Colocasia/Taro, boiled* (without salt)
# 4                  Colocasia/Taro/Tannia, cormel, raw
# 7   Colocasia/Taro/Tannia, cormel, boiled* (withou...
# 8                            Elephant foot, corm, raw
# 11        Elephant foot, corm, boiled* (without salt)
# 12                              Giant taro, corm, raw
# 15           Giant taro, corm, boiled* (without salt)
# 16                               Potato, Diamond, raw
# 19            Potato, Diamond, boiled* (without salt)
# 20                                       Potato Mash*
# 21    Sweet potato, Komola Sundori, orange flesh, raw
# 24  Sweet potato, Komola Sundori, orange flesh, bo...
# 25               Sweet potato, pale-yellow flesh, raw
# 28  Sweet potato, pale-yellow flesh, boiled* (with...
# 29  Sweet potato, skin purple, flesh pale yellow, ...
#
# ...

# %%
import pandas as pd

# Replace the file path with your actual file path
file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 5\Table 5_4_Starchy roots, tubers and their products.xlsx"

# Read Excel file
df = pd.read_excel(file_path)

# Drop rows with NaN values
df_cleaned = df.dropna()

# Remove the 'Code' column
data = df_cleaned.drop(['Code'], axis=1)

# Save the cleaned DataFrame to a CSV file
csv_file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 5\Table 5_4_Cleaned_Data.csv"
data.to_csv(csv_file_path, index=False)

# Display the first few rows of the cleaned DataFrame
data
# Out:
#                                 Food name in English  \
# 0  Sweet potato, skin purple, flesh pale  yellow,...
# 1                     Sweet potato, white flesh, raw
# 4  Sweet potato, white flesh, boiled* (without salt)
# 5                                    Yam, tuber, raw
# 8                 Yam, tuber, boiled* (without salt)
#
#                        Food name in Bengali  Edible portion coefficient  \
# 0  Misti alu, lal khosa, siddha lobon chara                        1.00
# 1                           Misti alu, sada                        0.84
# 4      Misti alu, sada, siddha, lobon chara                        1.00
# 5                  Bon alu, bivinno projati                        0.81
# 8               Bon alu siddha, lobon chara                        1.00
#
#   Energy (kcal) kJ  Water (g)  Protein (g)  Fat (g)  \
# 0        (106) 447       71.4          0.6      0.3
# 1         (98) 415       73.5          0.6      0.3
# ...

# %%
import pandas as pd

# Replace the file path with your actual file path
file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 6\Table 6_1_Nuts, seeds and their products.xlsx"

# Read Excel file
df = pd.read_excel(file_path)

# Drop rows with NaN values
df_cleaned = df.dropna()

# Remove the 'Code' column
data = df_cleaned.drop(['Code'], axis=1)

# Save the cleaned DataFrame to a CSV file
csv_file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 6\Table 6_1_Cleaned_Data.csv"
data.to_csv(csv_file_path, index=False)

# Display the first few rows of the cleaned DataFrame
data
# Out:
#           Food name in English Food name in Bengali  \
# 0       Sunflower seeds, dried       Surjomukhi bij
# 3             Cashew nuts, raw         Hizlee badam
# 6         Chilgoza pine, dried             Chilgoza
# 9                 Coconut milk         Narikel dudh
# 12         Coconut, desiccated      Narikel, shukna
# 15      Coconut, mature kernel              Narikel
# 18      Groundnuts/Peanut, raw          China badam
# 21        Jackfruit seeds, raw      Kathal er bichi
# 24                Linseed, raw                 Tisi
# 27          Lotus seeds, dried   Poddo gota, shukna
# 30          Lotus seeds, green   Poddo gota, kancha
# 33        Mustard seeds, dried              Sarisha
# 36       Pistachio nuts, dried                Pesta
# 39        Pumpkin seeds, dried    Mistikumrar bichi
# 42  Sesame seeds, whole, dried                  Til
# 45                     Walnuts               Akhrot
#
# ...

# %%
import pandas as pd

# Replace the file path with your actual file path
file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 7\Table 7_1_Spices, condiments and herbs.xlsx"

# Read Excel file
df = pd.read_excel(file_path)

# Drop rows with NaN values
df_cleaned = df.dropna()

# Remove the 'Code' column
data = df_cleaned.drop(['Code'], axis=1)

# Save the cleaned DataFrame to a CSV file
csv_file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 7\Table 7_1_Cleaned_Data.csv"
data.to_csv(csv_file_path, index=False)

# Display the first few rows of the cleaned DataFrame
data
# Out:
#      Food name in English Food name in Bengali  Edible portion coefficient  \
# 0         Bay leaf, dried              Tejpata                        1.00
# 2                Cardamom                Elach                        1.00
# 5        Chilli, red, dry        Shukna morich                        0.94
# 8        Cinnamon, ground        Darchini gura                        1.00
# 10          Cloves, dried              Labongo                        1.00
# 13  Coriander leaves, raw           Dhone pata                        0.70
# 16    Coriander seed, dry               Dhonia                        1.00
# 19            Cumin seeds                 Jira                        1.00
# 22           Fennel seeds                Mauri                        1.00
# 25        Fenugreek seeds                Methi                        1.00
# 28       Ginger root, raw                  Ada                        0.86
# ...

# %%
import pandas as pd

# Replace the file path with your actual file path
file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 7\Table 7_4_Spices, condiments and herbs.xlsx"

# Read Excel file
df = pd.read_excel(file_path)

# Drop rows with NaN values
df_cleaned = df.dropna()

# Remove the 'Code' column
data = df_cleaned.drop(['Code'], axis=1)

# Save the cleaned DataFrame to a CSV file
csv_file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 7\Table 7_4_Cleaned_Data.csv"
data.to_csv(csv_file_path, index=False)

# Display the first few rows of the cleaned DataFrame
data
# Out:
#        Food name in English Food name in Bengali  Edible portion coefficient  \
# 0             Nutmeg, dried               Jayfol                        0.85
# 3             Pepper, black            Golmorich                        1.00
# 6               Poppy seeds           Posto dana                        1.00
# 9   Spearmint leaves, fresh          Pudina pata                        0.45
# 12          Turmeric, dried                Holud                        1.00
#
#    Energy (kcal) kJ  Water (g)  Protein (g) Fat (g)  \
# 0        (480) 1980       14.3          7.5    36.4
# 3        (302) 1260       11.7         11.8     3.3
# 6        (523) 2160        5.7         17.2    43.1
# 9          (35) 143       87.4          3.0     0.7
# 12       (335) 1400       11.5          6.9     8.4
#
#     Carbohydrate available (g)  Total dietary fibre (g) Ash (g)
# 0                         21.1                     19.0     1.7
# ...

# %%
import pandas as pd

# Replace the file path with your actual file path
file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 15\Table 15_1_Miscellaneous.xlsx"

# Read Excel file
df = pd.read_excel(file_path)

# Drop rows with NaN values
df_cleaned = df.dropna()

# Remove the 'Code' column
data = df_cleaned.drop(['Code'], axis=1)

# Save the cleaned DataFrame to a CSV file
csv_file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 15\Table 15_1_Cleaned_Data.csv"
data.to_csv(csv_file_path, index=False)

# Display the first few rows of the cleaned DataFrame
data
# Out:
#           Food name in English Food name in Bengali  \
# 0                Baking powder        Baking powder
# 2            Betel leaves, raw             Pan pata
# 5                        Honey                Modhu
# 8    Jaggery, sugarcane, solid             Gur, Akh
# 10   Jaggery/Panela, date palm          Gur, Khejur
# 12  Jagggery liquid, date palm            Nolen gur
# 17                Sugar, white          Chini, sada
#
#     Edible portion coefficient Energy (kcal) kJ Water (g)  Protein (g)  \
# 0                          1.0        172 (731)       6.3          5.2
# 2                          1.0         (42) 175      85.4          3.1
# 5                          1.0       (326) 1390      18.2          0.3
# 8                          1.0       (385) 1630       3.4          0.5
# 10                         1.0       (352) 1500       9.6          1.5
# 12                         1.0         (86) 365      78.3          0.3
# ...

# %%
import pandas as pd

# Replace the file path with your actual file path
file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 1\Table 1_4_Cereals and their products.xlsx"

# Read Excel file
df = pd.read_excel(file_path)

# Drop rows with NaN values
df_cleaned = df.dropna()

# Remove the 'Code' column
data = df_cleaned.drop(['Code'], axis=1)

# Save the cleaned DataFrame to a CSV file
csv_file_path = r"F:\4th year 1st semester\Thesis\Data Collection\Collect From Kajol Bhai\Food Data\Table 1\Table 1_4_Cleaned_Data.csv"
data.to_csv(csv_file_path, index=False)

# Display the first few rows of the cleaned DataFrame
data
# Out:
#                                  Food name in English  \
# 0                 Rice, BR-28, boiled* (without salt)
# 1                 Rice, BR-11, parboiled, milled, raw
# 3                 Rice, BR-16, parboiled, milled, raw
# 5                 Rice, BR-26, parboiled, milled, raw
# 7                  Rice, BR-3, parboiled, milled, raw
# 9          Rice, BRRI Dhan-30, parboiled, milled, raw
# 11         Rice, BRRI Dhan-40, parboiled, milled, raw
# 13                                    Rice, bran, raw
# 16           Rice, brown, parboiled, homepounded, raw
# 20  Rice, brown, home-pounded, boiled* (without salt)
# 21                Rice, brown, parboiled, milled, raw
# 24  Rice, brown, parboiled, milled, boiled* (witho...
# 25                                       Rice, popped
# 28                               Rice, puffed, salted
# 31                 Rice, white, sunned, aromatic, raw
# 34  Rice, white, sunned, aromatic, boiled* (withou...
#
# ...
